# %% [markdown]
# # **Problem 1** - On paper

# %% [markdown]
# # **Problem 2**

# %% [markdown]
# ### a) - On paper

# %% [markdown]
# ### b) - On paper

# %% [markdown]
# ### c)

# %%
import numpy as np
import matplotlib.pyplot as plt

r_range = np.linspace(0, 4, 100000)
R = []
X = []

for r in r_range:
  R.append(r)
  x = np.random.random()

  for _ in range(100):
   x = 1 - r * x ** 2 + 0.4 * x

  X.append(x)


plt.plot(R, X, ls='', marker=',')
plt.ylim(-1, 2)
plt.xlim(0, 2.2)
plt.xlabel('r')
plt.ylabel('X')
plt.show()
# Out:
# <ipython-input-6-498fed65d2e9>:16: RuntimeWarning: overflow encountered in double_scalars
#   x= 1-r*x**2+0.4*x

# %% [markdown]
# ### d)

# %%
import numpy as np

a = 1.2
b = 0.4
x = y = 0
vec1 = [1, 0]
vec2 = [0, 1]

for i in range(490):
  xn = 1 - a*x*x + y
  yn = b*x
  x = xn
  y = yn
  J = np.array([[-2*a*x, 1], [b, 0]])
  vec1 = J.dot(vec1)
  vec2 = J.dot(vec2)
  dotprod1 = np.dot(vec1, vec1)
  dotprod2 = np.dot(vec1, vec2)
  vec2 = vec2 - np.multiply((dotprod2/dotprod1), vec1)
  lengthv1 = np.sqrt(dotprod1)
  area = np.multiply(vec1[0], vec2[1]) - np.multiply(vec1[1],vec2[0])
  h1 = np.log(lengthv1)/i
  h2 = np.log(area)/i-h1

print('h_1 = {}'.format(h1))
print('h_2 = {}'.format(h2))
# Out:
# h_1 = 0.3391568093091681
# h_2 = -1.2565387259040743
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: divide by zero encountered in double_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# # **Problem 3**

# %% [markdown]
# ### a)

# %%
import pylab as plt
import numpy as np

def plot_mandelbrot(z_power):
  loop = 50
  div = 600

  c = np.linspace(-2,2,div)[:,np.newaxis] + 1j*np.linspace(-2,2,div)[np.newaxis,:]
  ones = np.ones(np.shape(c), int)
  color = ones * loop + 5
  z = 0

  for n in range(0,loop):
        z = z**z_power + c
        diverged = np.abs(z)>2
        color[diverged] = np.minimum(color[diverged], ones[diverged]*n)

  plt.rcParams['figure.figsize'] = [12, 7.5]
  plt.contourf(c.real, c.imag, color)
  plt.xlabel("Real($c$)")
  plt.ylabel("Imag($c$)")
  plt.xlim(-2,2)
  plt.ylim(-1.5,1.5)
  plt.show()

plot_mandelbrot(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in square
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in square
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in absolute
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### b)

# %%
plot_mandelbrot(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in power
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in power
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in absolute
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### c)

# %%
plot_mandelbrot(4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in power
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in power
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in absolute
#   from ipykernel import kernelapp as app

# %% [markdown]
# # **Problem 4**

# %% [markdown]
# ### Plot the Julia set

# %%
import numpy as np
import matplotlib.pyplot as plt

def julia_set(c=0.5 + 0.3j, height=1000, width=1000, x=0, y=0, zoom=1, max_iterations=200):
    x_width = 1.5
    y_height = 1.5*height/width
    x_from = x - x_width/zoom
    x_to = x + x_width/zoom
    y_from = y - y_height/zoom
    y_to = y + y_height/zoom

    x = np.linspace(x_from, x_to, width).reshape((1, width))
    y = np.linspace(y_from, y_to, height).reshape((height, 1))
    z = x + 1j * y

    c = np.full(z.shape, c)

    div_time = np.zeros(z.shape, dtype=int)

    m = np.full(c.shape, True, dtype=bool)

    for i in range(max_iterations):
        z[m] = z[m]**2 + c[m]
        m[np.abs(z) > 2] = False
        div_time[m] = i

    return div_time

plt.imshow(julia_set(), cmap='magma')
plt.show()

# %% [markdown]
# ### a)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

c = complex(0.5, 0.3)
z = complex(0, 0)

for i in range(20):
  print(f'z{i}=' + str(z))

  z = z**2 + c

print()
print("About the orbit: the computation overflows. This means that the orbit of the point z=0 is going to be unbounded.")
# Out:
# z0=0j
# z1=(0.5+0.3j)
# z2=(0.66+0.6j)
# z3=(0.5756000000000001+1.092j)
# z4=(-0.36114864000000013+1.5571104000000004j)
# z5=(-1.7941644576143116-0.8246966065797128j)
# z6=(3.038901608062363+3.2592826796809073j)
# z7=(-0.88800060258394+20.109278752824235j)
# z8=(-403.09454688859876-35.41410330007269j)
# z9=(161231.5550187765+28550.76384641766j)
# z10=(25180468218.058846+9206568104.163567j)
# z11=(5.4929508342406965e+20+4.6365139108856994e+20j)
# z12=(8.6752476215489625e+40+5.093628590953639e+41j)
# z13=(-2.5192453009628443e+83+8.83769786374487e+82j)
# z14=(5.5655478511149655e+166-4.452865762913726e+166j)
# z15=(nan+nanj)
# z16=(nan+nanj)
# z17=(nan+nanj)
# z18=(nan+nanj)
# z19=(nan+nanj)
#
# About the orbit: the computation overflows. This means that the orbit of the point z=0 is going to be unbounded.

# %% [markdown]
# ### b)

# %%
c = complex(0.5, 0.3)
z = complex(-1, -1)

for i in range(11):
  print(f'z{i}=' + str(z))

  z = z**2 + c

print()
print("About the orbit: with every iteration the number is getting bigger. This means that the orbit is going to be unbounded.")
# Out:
# z0=(-1-1j)
# z1=(0.5+2.3j)
# z2=(-4.539999999999999+2.5999999999999996j)
# z3=(14.351599999999994-23.307999999999993j)
# z4=(-336.7944414399999-668.7141855999996j)
# z5=(-333747.6662377892+450438.74124431255j)
# z6=(-91507554894.09-300665757346.4534j)
# z7=(-8.202626503802152e+22+5.502637659030746e+22j)
# z8=(3.700406035429414e+45-9.027216300557084e+45j)
# z9=(-6.77976293100011e+91-6.680873136341645e+91j)
# z10=(1.3311195366717695e+182+9.058947207296707e+183j)
#
# About the orbit: with every iteration the number is getting bigger. This means that the orbit is going to be unbounded.

# %% [markdown]
# # **Problem 5** - on paper
